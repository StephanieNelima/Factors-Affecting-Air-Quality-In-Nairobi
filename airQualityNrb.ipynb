# %%
import pandas as pd
import numpy as  np

# %%
nrb_gcp=pd.read_csv('NairobiGCP.csv')
nrb_population=pd.read_csv('Nairobi-Population-Total-Population-By-Year-2026-04-24-04-23.csv')
nrb_pm19=pd.read_csv('june_2019_sensor_data_archive.csv')
nrb_pm18=pd.read_csv('june_2018_sensor_data_archive.csv')
nrb_pm17=pd.read_csv('june_2017_sensor_data_archive.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5883/259622036.py in <cell line: 0>()
# ----> 1 nrb_gcp=pd.read_csv('NairobiGCP.csv')
#       2 nrb_population=pd.read_csv('Nairobi-Population-Total-Population-By-Year-2026-04-24-04-23.csv')
#       3 nrb_pm19=pd.read_csv('june_2019_sensor_data_archive.csv')
#       4 nrb_pm18=pd.read_csv('june_2018_sensor_data_archive.csv')
#       5 nrb_pm17=pd.read_csv('june_2017_sensor_data_archive.csv')
#
# ...

# %%
nrb_gcp.head(20)

# %%
nrb_gcp.drop(nrb_gcp.index[0:6],inplace=True)
nrb_gcp.rename(columns={'Table':'Year','T2':'GCP(Kes)'},inplace=True)

# %%
nrb_gcp.head()

# %%
nrb_gcp.describe()

# %%
nrb_population.head(70)
nrb_population.drop(nrb_population.index[0:67],inplace=True)
nrb_population.drop(nrb_population.index[70:76],inplace=True)
#nrb_gcp.rename(columns={'Table':'Year','T2':'GCP(Kes)'},inplace=True)

# %%
#nrb_population.drop(70)
nrb_population.head(10)
# Out:
#     Unnamed: 0  Population
# 67        2017     4222000
# 68        2018     4386000
# 69        2019     4556000
# 70        2020     4735000
# 71        2021     4922000
# 72        2022     5119000
# 73        2023     5325000
# 74        2024     5541000
# 75        2025     5767000
